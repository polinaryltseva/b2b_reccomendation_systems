# %%
import polars as pl
import numpy as np

# %% [markdown]
# # 2020

# %% [markdown]
# ## Создаем список торгов

# %%
df = pl.read_excel(source='correct_data/correct_data_2020.xlsx')
df = df.select(['ИНН заказчика', 'Реестровый номер публикации'])
df = df.rename({'Реестровый номер публикации':'pub_num'})
df = df.unique().sort('pub_num')
df
# Out:
# shape: (63_634, 2)
# ┌───────────────┬─────────────────────┐
# │ ИНН заказчика ┆ pub_num             │
# │ ---           ┆ ---                 │
# │ str           ┆ str                 │
# ╞═══════════════╪═════════════════════╡
# │ 0276090428    ┆ 0101100001120000001 │
# │ 2014030545    ┆ 0101100009420000001 │
# │ 2014030545    ┆ 0101100009420000002 │
# │ 0261014135    ┆ 0101200002320000001 │
# │ 0261014135    ┆ 0101200002320000002 │
# │ …             ┆ …                   │
# │ 0276143694    ┆ 3961555             │
# │ 0276143694    ┆ 3963183             │
# │ 0276143694    ┆ 3963353             │
# │ 0276143694    ┆ 3964329             │
# │ 6315376946    ┆ 54383               │
# └───────────────┴─────────────────────┘

# %%
df.write_excel()

# %% [markdown]
# ## Проверяем сколько закупок по каждому фз

# %%
d = pl.read_excel('zakgov/data_for_parsing_2020.xlsx')
d
# Out:
# shape: (63_634, 2)
# ┌───────────────┬─────────────────────┐
# │ ИНН заказчика ┆ pub_num             │
# │ ---           ┆ ---                 │
# │ str           ┆ str                 │
# ╞═══════════════╪═════════════════════╡
# │ 0276090428    ┆ 0101100001120000001 │
# │ 2014030545    ┆ 0101100009420000001 │
# │ 2014030545    ┆ 0101100009420000002 │
# │ 0261014135    ┆ 0101200002320000001 │
# │ 0261014135    ┆ 0101200002320000002 │
# │ …             ┆ …                   │
# │ 0276143694    ┆ 3961555             │
# │ 0276143694    ┆ 3963183             │
# │ 0276143694    ┆ 3963353             │
# │ 0276143694    ┆ 3964329             │
# │ 6315376946    ┆ 54383               │
# └───────────────┴─────────────────────┘

# %%
print(f"Закупки по 44/94 ФЗ: {d.filter(pl.col('pub_num').str.len_chars()==19).shape[0]}")
print(f"Закупки с других площадок: {d.filter(pl.col('pub_num').str.len_chars()==7).shape[0]}")
print(f"Закупки по 223 ФЗ: {d.filter(pl.col('pub_num').str.len_chars()==11).shape[0]}")
# Out:
# Закупки по 44/94 ФЗ: 12974
# Закупки с других площадок: 1799
# Закупки по 223 ФЗ: 48860

# %% [markdown]
# ### Нашли тендеры с несколькими участниками

# %%
g = d.filter(pl.col('pub_num').str.len_chars()==19)
g = g.group_by(pl.col('pub_num')).agg(pl.col('ИНН заказчика').count().alias('n'))
g.filter(pl.col('n')>1)
# Out:
# shape: (25, 2)
# ┌─────────────────────┬─────┐
# │ pub_num             ┆ n   │
# │ ---                 ┆ --- │
# │ str                 ┆ u32 │
# ╞═════════════════════╪═════╡
# │ 0131300045220000003 ┆ 13  │
# │ 0301300332920000014 ┆ 27  │
# │ 0360300287820000004 ┆ 16  │
# │ 0301300332920000001 ┆ 27  │
# │ 0301300332920000002 ┆ 27  │
# │ …                   ┆ …   │
# │ 0301300332920000012 ┆ 22  │
# │ 0301300332920000008 ┆ 27  │
# │ 0360300287820000005 ┆ 10  │
# │ 0131300045220000002 ┆ 21  │
# │ 0301300332920000004 ┆ 4   │
# └─────────────────────┴─────┘

# %% [markdown]
# ## Парсинг 2020

# %%
import json

with open('zakgov/result_zakgov_2020.json', 'r') as f:
    data = json.load(f)


ozoik = pl.from_dicts(data)
ozoik
# Out:
# shape: (61_086, 5)
# ┌─────────────────────┬────────┬────────────────────────────────┬──────────────────┬─────────┐
# │ pub_num             ┆ price  ┆ oz                             ┆ oik              ┆ no_info │
# │ ---                 ┆ ---    ┆ ---                            ┆ ---              ┆ ---     │
# │ str                 ┆ str    ┆ str                            ┆ str              ┆ i64     │
# ╞═════════════════════╪════════╪════════════════════════════════╪══════════════════╪═════════╡
# │ 0101100001120000001 ┆        ┆                                ┆                  ┆ 0       │
# │                     ┆ 2 000… ┆         20 000,00 РОССИЙСКИЙ … ┆                  ┆         │
# │                     ┆        ┆                                ┆                  ┆         │
# │                     ┆        ┆                                ┆             100… ┆         │
# │ 0101200002320000001 ┆        ┆                                ┆                  ┆ 0       │
# │                     ┆ 16 50… ┆         165 000,00 РОССИЙСКИЙ… ┆                  ┆         │
# │                     ┆        ┆                                ┆                  ┆         │
# │                     ┆        ┆                                ┆             825… ┆         │
# │ 0101200002320000002 ┆        ┆                                ┆                  ┆ 0       │
# │                     ┆ 4 000… ┆         40 000,00 РОССИЙСКИЙ … ┆                  ┆         │
# │                     ┆        ┆                                ┆                  ┆         │
# │                     ┆        ┆                                ┆                  ┆         │
# │                     ┆        ┆                                ┆       …          ┆         │
# │ 0101200009320000001 ┆        ┆ null                           ┆                  ┆ 0       │
# │                     ┆ 22 68… ┆                                ┆                  ┆         │
# │                     ┆        ┆                                ┆                  ┆         │
# │                     ┆        ┆                                ┆             2 2… ┆         │
# │ 0101100009420000002 ┆        ┆ null                           ┆                  ┆ 0       │
# │                     ┆ 634 1… ┆                                ┆                  ┆         │
# │                     ┆        ┆                                ┆                  ┆         │
# │                     ┆        ┆                                ┆             31 … ┆         │
# │ …                   ┆ …      ┆ …                              ┆ …                ┆ …       │
# │ 32514569675         ┆        ┆ null                           ┆ null             ┆ 0       │
# │                     ┆ …      ┆                                ┆                  ┆         │
# │ 32514571035         ┆        ┆ null                           ┆ null             ┆ 0       │
# │                     ┆ …      ┆                                ┆                  ┆         │
# │ 32514570297         ┆        ┆ null                           ┆ null             ┆ 0       │
# │                     ┆ …      ┆                                ┆                  ┆         │
# │ 32514569911         ┆        ┆ null                           ┆ null             ┆ 0       │
# │                     ┆ …      ┆                                ┆                  ┆         │
# │ 32514570868         ┆        ┆ null                           ┆ null             ┆ 0       │
# │                     ┆ …      ┆                                ┆                  ┆         │
# └─────────────────────┴────────┴────────────────────────────────┴──────────────────┴─────────┘

# %%
ozoik = ozoik.drop('no_info')
ozoik = ozoik.select('pub_num', 'price')

# %%
ozoik.write_excel()

# %% [markdown]
# ## Делаем нормальные значения цены

# %%
ozoik.write_json()
# Out:
# '[{"pub_num":"0101100001120000001","price":"\\n                        2\xa0000\xa0000,00 ₽\\n                    "},{"pub_num":"0101200002320000001","price":"\\n                        16\xa0500\xa0000,00 ₽\\n                    "},{"pub_num":"0101200002320000002","price":"\\n                        4\xa0000\xa0000,00 ₽\\n                    "},{"pub_num":"0101200009320000001","price":"\\n                        22\xa0683,33 ₽\\n                    "},{"pub_num":"0101100009420000002","price":"\\n                        634\xa0190,67 ₽\\n                    "},{"pub_num":"0101100009420000001","price":"\\n                        990\xa0427,50 ₽\\n                    "},{"pub_num":"0101200008020000001","price":"\\n                        300\xa0000,00 ₽\\n                    "},{"pub_num":"0101200002320000003","price":"\\n                        3\xa0904\xa0221,54 ₽\\n                    "},{"pub_num":"0101200008620000001","price":"\\n                        450\xa0000,00 ₽\\n                    "},{"pub_num":"0101200009820000001","price":"\\n                        109\xa0901,00 ₽\\n                    "},{"pub_num":"0101200009820000003","price":"\\n                        319\xa0852,65 ₽\\n                    "},{"pub_num":"0101200009820000002","price":"\\n                        1\xa0013\xa0320,00 ₽\\n                    "},{"pub_num":"0101200010220000001","price":"\\n                        930\xa0264,48 ₽\\n                    "},{"pub_num":"0101200010520000002","price":"\\n                        960\xa0000,00 ₽\\n                    "},{"pub_num":"0101200010520000001","price":"\\n                        468\xa0000,00 ₽\\n                    "},{"pub_num":"0101200012020000002","price":"\\n                        1\xa0959\xa0999,91 ₽\\n                    "},{"pub_num":"0101200012020000001","price":"\\n                        128\xa0271,00 ₽\\n                    "},{"pub_num":"0101200012020000003","price":"\\n                        605\xa0000,00 ₽\\n                    "},{"pub_num":"0101300000120000001","price":"\\n                        185\xa0112,00 ₽\\n                    "},{"pub_num":"0101200012020000004","price":"\\n                        605\xa0880,00 ₽\\n                    "},{"pub_num":"0101300000220000002","price":"\\n                        42\xa0500,00 ₽\\n                    "},{"pub_num":"0101300000120000002","price":"\\n                        710\xa0361,36 ₽\\n                    "},{"pub_num":"0101300000220000003","price":"\\n                        52\xa0000,00 ₽\\n                    "},{"pub_num":"0101300000220000001","price":"\\n                        341\xa0000,00 ₽\\n                    "},{"pub_num":"0101300000620000001","price":"\\n                        278\xa0716,82 ₽\\n                    "},{"pub_num":"0101300001820000001","price":"\\n                        200\xa0000,00 ₽\\n                    "},{"pub_num":"0101300000620000004","price":"\\n                        663\xa0017,81 ₽\\n                    "},{"pub_num":"0101300001820000002","price":"\\n                        88\xa0400,00 ₽\\n                    "},{"pub_num":"0101300006320000001","price":"\\n                        3\xa0796\xa0000,00 ₽\\n                    "},{"pub_num":"0101300000620000003","price":"\\n                        205\xa0574,45 ₽\\n                    "},{"pub_num":"0101300004620000001","price":"\\n                        1\xa0280\xa0487,60 ₽\\n                    "},{"pub_num":"0101300001920000001","price":"\\n                        4\xa0992\xa0000,00 ₽\\n                    "},{"pub_num":"0101300006320000002","price":"\\n                        1\xa0700\xa0000,00 ₽\\n                    "},{"pub_num":"0101300000620000002","price":"\\n                        394\xa0643,04 ₽\\n                    "},{"pub_num":"0101300006320000004","price":"\\n                        200\xa0000,00 ₽\\n                    "},{"pub_num":"0101300006320000003","price":"\\n                        27\xa0427,68 ₽\\n                ...

# %% [markdown]
# # 2015

# %% [markdown]
# ## Делаем нормальные значения oz и oik

# %%
ozoik = ozoik.rename({'oz':'обеспечение заявки', 
                      'oik':'обеспечение исполнения контракта',  
                      'pub_num':'Реестровый номер публикации'})

# %%
# исправляем oz
ozoik = ozoik.with_columns(pl.col("обеспечение заявки")
                                   .str.extract(r"([\d\xa0,]+)")
                                   .str.replace_all("\xa0", "")
                                   .str.replace(",", ".")
                                   .cast(pl.Float64)
                                   .alias("обеспечение заявки"))

# %%
# сиправляем oik
ozoik = ozoik.with_columns(
                    pl.col("обеспечение исполнения контракта")
                    .str.extract(r'([\d\xa0,]+)\s*₽')
                    .str.replace_all(r'[\xa0,]', '')
                    .cast(pl.Float64)
                    .alias("numeric_value"),
                
                    pl.col("обеспечение исполнения контракта")
                    .str.extract(r'\(?(\d+,\d+|\d+)\s*%\)?')
                    .str.replace(',', '.')
                    .cast(pl.Float64)
                    .alias("percentage_value"))

#ozoik = ozoik.with_columns(pl.when((pl.col('numeric_value').is_not_null()) & (pl.col('percentage_value').is_not_null())).then(pl.lit(None)).otherwise(pl.col('numeric_value')).alias('numeric_value'))

ozoik = ozoik.rename({'numeric_value':'обеспечение исполнения контракта, руб', 'percentage_value': 'обеспечение исполнения контракта, %'})
ozoik = ozoik.with_columns(pl.col('обеспечение исполнения контракта, %')/100)
ozoik
# Out:
# shape: (12_974, 6)
# ┌───────────────────────┬─────────────┬─────────────┬─────────┬─────────────┬──────────────────────┐
# │ Реестровый номер      ┆ обеспечение ┆ обеспечение ┆ no_info ┆ обеспечение ┆ обеспечение          │
# │ публикации            ┆ заявки      ┆ исполнения  ┆ ---     ┆ исполнения  ┆ исполнения контрак…  │
# │ ---                   ┆ ---         ┆ контрак…    ┆ i64     ┆ контрак…    ┆ ---                  │
# │ str                   ┆ f64         ┆ ---         ┆         ┆ ---         ┆ f64                  │
# │                       ┆             ┆ str         ┆         ┆ f64         ┆                      │
# ╞═══════════════════════╪═════════════╪═════════════╪═════════╪═════════════╪══════════════════════╡
# │ 0101100001120000001   ┆ 20000.0     ┆             ┆ 0       ┆ 1e7         ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆ 100…        ┆         ┆             ┆                      │
# │ 0101100009420000002   ┆ null        ┆             ┆ 0       ┆ 3.170953e6  ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆ 31 …        ┆         ┆             ┆                      │
# │ 0101200002320000002   ┆ 40000.0     ┆             ┆ 0       ┆ null        ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆       …     ┆         ┆             ┆                      │
# │ 0101100009420000001   ┆ null        ┆             ┆ 0       ┆ 4.952138e6  ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆ 49 …        ┆         ┆             ┆                      │
# │ 0101200008020000001   ┆ null        ┆             ┆ 0       ┆ null        ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆       …     ┆         ┆             ┆                      │
# │ …                     ┆ …           ┆ …           ┆ …       ┆ …           ┆ …                    │
# │ 2071500000120000002   ┆ null        ┆             ┆ 0       ┆ 2.802586e6  ┆ null                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆ 28 …        ┆         ┆             ┆                      │
# │ 2074700000120000001   ┆ 14400.0     ┆             ┆ 0       ┆ null        ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆       …     ┆         ┆             ┆                      │
# │ 2084700000120000001   ┆ null        ┆             ┆ 0       ┆ null        ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆       …     ┆         ┆             ┆                      │
# │ 2078500000120000003   ┆ 24094.26    ┆             ┆ 0       ┆ 1.204713e7  ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆ 120…        ┆         ┆             ┆                      │
# │ 2084700000120000002   ┆ null        ┆             ┆ 0       ┆ null        ┆ 0.05                 │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆             ┆         ┆             ┆                      │
# │                       ┆             ┆       …     ┆         ┆             ┆                      │
# └───────────────────────┴─────────────┴─────────────┴─────────┴─────────────┴──────────────────────┘

# %%
ozoik = ozoik.drop('no_info')

# %% [markdown]
# ## Соединяем с основным датафреймом

# %%
data = pl.read_excel(source='correct_data/correct_data_2020.xlsx')
data.shape
# Out:
# (109900, 26)

# %%
data = data.join(other=ozoik.unique('Реестровый номер публикации'), how='left', on=['Реестровый номер публикации'])
data
# Out:
# shape: (109_900, 30)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Уровень ┆ Заказчик   ┆ ИНН       ┆ Стоимость ┆ … ┆ обеспечен ┆ обеспечен ┆ обеспечен ┆ обеспечен │
# │ ---     ┆ ---        ┆ заказчика ┆ (руб.)    ┆   ┆ ие заявки ┆ ие исполн ┆ ие исполн ┆ ие исполн │
# │ i64     ┆ str        ┆ ---       ┆ Заказчик  ┆   ┆ ---       ┆ ения      ┆ ения      ┆ ения      │
# │         ┆            ┆ str       ┆ ---       ┆   ┆ f64       ┆ контрак…  ┆ контрак…  ┆ контрак…  │
# │         ┆            ┆           ┆ f64       ┆   ┆           ┆ ---       ┆ ---       ┆ ---       │
# │         ┆            ┆           ┆           ┆   ┆           ┆ str       ┆ f64       ┆ f64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2       ┆ ГБУЗ АО    ┆ 301800569 ┆ 49120.0   ┆ … ┆ null      ┆           ┆ null      ┆ 0.05      │
# │         ┆ "ГКБ №3"   ┆ 3         ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆       …   ┆           ┆           │
# │ 1       ┆ ФГБУ       ┆ 770643326 ┆ 420000.0  ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │         ┆ "ВИМС"     ┆ 3         ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2       ┆ ООО "БСК"  ┆ 027305675 ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │         ┆            ┆ 7         ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1       ┆ ИСПМ РАН   ┆ 772802124 ┆ 366354.41 ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │         ┆            ┆ 9         ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1       ┆ ФГАОУ ДПО  ┆ 771808406 ┆ 495702.0  ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │         ┆ "АКАДЕМИЯ  ┆ 3         ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆ МИНПРОСВЕЩ ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆ …          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …       ┆ …          ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2       ┆ ГКБСМП     ┆ 390604084 ┆ 96283.83  ┆ … ┆ null      ┆           ┆ null      ┆ 0.05      │
# │         ┆            ┆ 0         ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆       …   ┆           ┆           │
# │ 1       ┆ КГКУ       ┆ 271301220 ┆ 519830.0  ┆ … ┆ null      ┆           ┆ 2.59915e6 ┆ 0.05      │
# │         ┆ ХОРСКИЙ    ┆ 3         ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆ СРЦ        ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆ 25 …      ┆           ┆           │
# │ 2       ┆ КОМИТЕТ    ┆ 290201200 ┆ 5.922485e ┆ … ┆ 59224.85  ┆           ┆ null      ┆ 0.15      │
# │         ┆ ЖКХ, ТИС   ┆ 8         ┆ 6         ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆       …   ┆           ┆           │
# │ 2       ┆ ГКУ КК ЦЗН ┆ 233002793 ┆ 91333.32  ┆ … ┆ 913.33    ┆           ┆ null      ┆ 0.05      │
# │         ┆ ДИНСКОГО   ┆ 5         ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆ РАЙОНА     ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆       …   ┆           ┆           │
# │ 2       ┆ ООО        ┆ 631923104 ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │         ┆ "САМЭСК"   ┆ 2         ┆           ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
check_oik = data.with_columns(pl.when(pl.col('Обеспечение контракта (руб.)').is_not_null()).then(1).otherwise(0).alias('oldr'))
check_oik = check_oik.with_columns(pl.when(pl.col('Обеспечение контракта, %').is_not_null()).then(1).otherwise(0).alias('oldpr'))
check_oik = check_oik.with_columns((pl.col('oldr')+pl.col('oldpr')).alias('old'))
check_oik = check_oik.with_columns(pl.when(pl.col('old')>0).then(1).otherwise(0).alias('old'))

check_oik = check_oik.with_columns(pl.when(pl.col('обеспечение исполнения контракта, руб').is_not_null()).then(1).otherwise(0).alias('newr'))
check_oik = check_oik.with_columns(pl.when(pl.col('обеспечение исполнения контракта, %').is_not_null()).then(1).otherwise(0).alias('newpr'))
check_oik = check_oik.with_columns((pl.col('newr')+pl.col('newpr')).alias('new'))
check_oik = check_oik.with_columns(pl.when(pl.col('new')>0).then(1).otherwise(0).alias('new'))
check_oik = check_oik.drop(['oldr','oldpr', 'newr', 'newpr'])
check_oik.filter(pl.col('old')!=pl.col('new'))
# Out:
# shape: (0, 32)
# ┌─────────┬──────────┬───────────┬────────────────┬───┬────────────────┬───────────────┬─────┬─────┐
# │ Уровень ┆ Заказчик ┆ ИНН       ┆ Стоимость(руб. ┆ … ┆ обеспечение    ┆ обеспечение   ┆ old ┆ new │
# │ ---     ┆ ---      ┆ заказчика ┆ ) Заказчик     ┆   ┆ исполнения     ┆ исполнения    ┆ --- ┆ --- │
# │ i64     ┆ str      ┆ ---       ┆ ---            ┆   ┆ контрак…       ┆ контрак…      ┆ i32 ┆ i32 │
# │         ┆          ┆ str       ┆ f64            ┆   ┆ ---            ┆ ---           ┆     ┆     │
# │         ┆          ┆           ┆                ┆   ┆ f64            ┆ f64           ┆     ┆     │
# ╞═════════╪══════════╪═══════════╪════════════════╪═══╪════════════════╪═══════════════╪═════╪═════╡
# └─────────┴──────────┴───────────┴────────────────┴───┴────────────────┴───────────────┴─────┴─────┘

# %% [markdown]
# короче, ничего нового не нашли(

# %%
check_oz = data.with_columns(pl.when(pl.col('Обеспечение заявки (руб.)').is_not_null()).then(1).otherwise(0).alias('oldr'))
check_oz = check_oz.with_columns(pl.when(pl.col('Обеспечение заявки, %').is_not_null()).then(1).otherwise(0).alias('oldpr'))
check_oz = check_oz.with_columns((pl.col('oldr')+pl.col('oldpr')).alias('old'))
check_oz = check_oz.with_columns(pl.when(pl.col('old')>0).then(1).otherwise(0).alias('old'))

check_oz = check_oz.with_columns(pl.when(pl.col('обеспечение заявки').is_not_null()).then(1).otherwise(0).alias('new'))
check_oz = check_oz.drop(['oldr','oldpr'])
check_oz.filter(pl.col('old')!=pl.col('new'))
# Out:
# shape: (4_353, 32)
# ┌─────────┬──────────────┬──────────────┬──────────────┬───┬─────────────┬─────────────┬─────┬─────┐
# │ Уровень ┆ Заказчик     ┆ ИНН          ┆ Стоимость(ру ┆ … ┆ обеспечение ┆ обеспечение ┆ old ┆ new │
# │ ---     ┆ ---          ┆ заказчика    ┆ б.) Заказчик ┆   ┆ исполнения  ┆ исполнения  ┆ --- ┆ --- │
# │ i64     ┆ str          ┆ ---          ┆ ---          ┆   ┆ контрак…    ┆ контрак…    ┆ i32 ┆ i32 │
# │         ┆              ┆ str          ┆ f64          ┆   ┆ ---         ┆ ---         ┆     ┆     │
# │         ┆              ┆              ┆              ┆   ┆ f64         ┆ f64         ┆     ┆     │
# ╞═════════╪══════════════╪══════════════╪══════════════╪═══╪═════════════╪═════════════╪═════╪═════╡
# │ 2       ┆ АО "ИЭМЗ     ┆ 1831083343   ┆ null         ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │         ┆ "КУПОЛ"      ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# │ 1       ┆ АО "МОСВОДОК ┆ 7701984274   ┆ 3.8429e7     ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │         ┆ АНАЛ"        ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# │ 2       ┆ АО "МОСВОДОК ┆ 7701984274   ┆ null         ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │         ┆ АНАЛ"        ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# │ 2       ┆ АО "МОСВОДОК ┆ 7701984274   ┆ null         ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │         ┆ АНАЛ"        ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# │ 1       ┆ МУП АГО      ┆ 3801006828   ┆ 659411.44    ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │         ┆ "АНГАРСКИЙ   ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# │         ┆ ВОДОКАНАЛ"   ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# │ …       ┆ …            ┆ …            ┆ …            ┆ … ┆ …           ┆ …           ┆ …   ┆ …   │
# │ 1       ┆ АО "ВОЭ"     ┆ 3443029580   ┆ 1.2291e7     ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │ 1       ┆ АО "ОЗК"     ┆ 7708632345   ┆ 1.4832e8     ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │ 2       ┆ БАНК ВТБ     ┆ 7702070139   ┆ null         ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │         ┆ (ПАО)        ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# │ 2       ┆ АО "ОЗК"     ┆ 7708632345   ┆ null         ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │ 2       ┆ МУП АГО      ┆ 3801006828   ┆ null         ┆ … ┆ null        ┆ null        ┆ 1   ┆ 0   │
# │         ┆ "АНГАРСКИЙ   ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# │         ┆ ВОДОКАНАЛ"   ┆              ┆              ┆   ┆             ┆             ┆     ┆     │
# └─────────┴──────────────┴──────────────┴──────────────┴───┴─────────────┴─────────────┴─────┴─────┘

# %% [markdown]
# все максимально печально

# %%
check_oz.filter(pl.col('Реестровый номер публикации')=='32110158113')
# Out:
# shape: (7, 32)
# ┌─────────┬──────────┬───────────────┬───────────────┬───┬──────────────┬──────────────┬─────┬─────┐
# │ Уровень ┆ Заказчик ┆ ИНН заказчика ┆ Стоимость(руб ┆ … ┆ обеспечение  ┆ обеспечение  ┆ old ┆ new │
# │ ---     ┆ ---      ┆ ---           ┆ .) Заказчик   ┆   ┆ исполнения   ┆ исполнения   ┆ --- ┆ --- │
# │ i64     ┆ str      ┆ str           ┆ ---           ┆   ┆ контрак…     ┆ контрак…     ┆ i32 ┆ i32 │
# │         ┆          ┆               ┆ f64           ┆   ┆ ---          ┆ ---          ┆     ┆     │
# │         ┆          ┆               ┆               ┆   ┆ f64          ┆ f64          ┆     ┆     │
# ╞═════════╪══════════╪═══════════════╪═══════════════╪═══╪══════════════╪══════════════╪═════╪═════╡
# │ 2       ┆ БАНК ВТБ ┆ 7702070139    ┆ null          ┆ … ┆ null         ┆ null         ┆ 1   ┆ 0   │
# │         ┆ (ПАО)    ┆               ┆               ┆   ┆              ┆              ┆     ┆     │
# │ 2       ┆ БАНК ВТБ ┆ 7702070139    ┆ null          ┆ … ┆ null         ┆ null         ┆ 1   ┆ 0   │
# │         ┆ (ПАО)    ┆               ┆               ┆   ┆              ┆              ┆     ┆     │
# │ 2       ┆ БАНК ВТБ ┆ 7702070139    ┆ null          ┆ … ┆ null         ┆ null         ┆ 1   ┆ 0   │
# │         ┆ (ПАО)    ┆               ┆               ┆   ┆              ┆              ┆     ┆     │
# │ 2       ┆ БАНК ВТБ ┆ 7702070139    ┆ null          ┆ … ┆ null         ┆ null         ┆ 1   ┆ 0   │
# │         ┆ (ПАО)    ┆               ┆               ┆   ┆              ┆              ┆     ┆     │
# │ 2       ┆ БАНК ВТБ ┆ 7702070139    ┆ null          ┆ … ┆ null         ┆ null         ┆ 1   ┆ 0   │
# │         ┆ (ПАО)    ┆               ┆               ┆   ┆              ┆              ┆     ┆     │
# │ 2       ┆ БАНК ВТБ ┆ 7702070139    ┆ null          ┆ … ┆ null         ┆ null         ┆ 1   ┆ 0   │
# │         ┆ (ПАО)    ┆               ┆               ┆   ┆              ┆              ┆     ┆     │
# │ 2       ┆ БАНК ВТБ ┆ 7702070139    ┆ null          ┆ … ┆ null         ┆ null         ┆ 1   ┆ 0   │
# │         ┆ (ПАО)    ┆               ┆               ┆   ┆              ┆              ┆     ┆     │
# └─────────┴──────────┴───────────────┴───────────────┴───┴──────────────┴──────────────┴─────┴─────┘

# %% [markdown]
# ## Заполним пропуски

# %%
data = pl.read_excel(source='correct_data/correct_data_2020.xlsx')

# %%
data.columns
# Out:
# ['Уровень',
#  'Заказчик',
#  'ИНН заказчика',
#  'Стоимость(руб.) Заказчик',
#  'Реестровый номер публикации',
#  'Идентификационный код закупки',
#  'Сфера деятельности',
#  'Регион поставки',
#  'Город поставки',
#  'Дата публикации',
#  'Дата окончания приема заявок / Дата планового окончания исполнения контракта / Плановая дата публикации лота по ППГ',
#  'Дата начала подачи заявок / Дата начала исполнения контракта / Дата публикации ППГ',
#  'Дата окончания проведения торгов',
#  'Поставщик',
#  'ИНН поставщика',
#  'Победитель',
#  'Статус допуска',
#  'Снижение на торгах,%',
#  'Форма публикации',
#  'Тип торгов',
#  'Обеспечение заявки (руб.)',
#  'Обеспечение заявки, %',
#  'Обеспечение контракта (руб.)',
#  'Обеспечение контракта, %',
#  'РНП сейчас',
#  'РНП ранее']

# %%
data.filter(pl.col('Стоимость(руб.) Заказчик').is_not_null() & 
            pl.col('Обеспечение заявки (руб.)').is_not_null() &
            pl.col('Обеспечение заявки, %').is_null())
# Out:
# shape: (2_340, 26)
# ┌─────────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬────────┬───────────┐
# │ Уровень ┆ Заказчик   ┆ ИНН        ┆ Стоимость( ┆ … ┆ Обеспечени ┆ Обеспечен ┆ РНП    ┆ РНП ранее │
# │ ---     ┆ ---        ┆ заказчика  ┆ руб.)      ┆   ┆ е          ┆ ие контра ┆ сейчас ┆ ---       │
# │ i64     ┆ str        ┆ ---        ┆ Заказчик   ┆   ┆ контракта  ┆ кта, %    ┆ ---    ┆ i64       │
# │         ┆            ┆ str        ┆ ---        ┆   ┆ (руб.)     ┆ ---       ┆ i64    ┆           │
# │         ┆            ┆            ┆ f64        ┆   ┆ ---        ┆ f64       ┆        ┆           │
# │         ┆            ┆            ┆            ┆   ┆ f64        ┆           ┆        ┆           │
# ╞═════════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪════════╪═══════════╡
# │ 1       ┆ ОГКУ       ┆ 3906147174 ┆ 3.0000e6   ┆ … ┆ 149999.93  ┆ null      ┆ 0      ┆ 0         │
# │         ┆ "ЦЕНТР     ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ СОЦИАЛЬНОЙ ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ ПОДДЕРЖ…   ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 1       ┆ АО "МОСВОД ┆ 7701984274 ┆ 3.8429e7   ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ОКАНАЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 1       ┆ АДМИНИСТРА ┆ 5513001802 ┆ 1.541188e6 ┆ … ┆ 77059.4    ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ЦИЯ ЗНАМЕН ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ СКОГО      ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ МУНИ…      ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 1       ┆ МУП АГО    ┆ 3801006828 ┆ 659411.44  ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ "АНГАРСКИЙ ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ ВОДОКАНАЛ" ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 1       ┆ АО "МОСВОД ┆ 7701984274 ┆ 1.7820e7   ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ОКАНАЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ …       ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …         ┆ …      ┆ …         │
# │ 1       ┆ ГУ-ТОМСКОЕ ┆ 7018003855 ┆ 259529.78  ┆ … ┆ 12976.49   ┆ null      ┆ 0      ┆ 0         │
# │         ┆ РО ФОНДА   ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ СОЦИАЛЬНОГ ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ …          ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 1       ┆ АДМИНИСТРА ┆ 1433017567 ┆ 3.9083e6   ┆ … ┆ 195415.71  ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ЦИЯ МР "МИ ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ РНИНСКИЙ   ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ Р…         ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 1       ┆ АО "МОСВОД ┆ 7701984274 ┆ 2.0783e7   ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ОКАНАЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 1       ┆ АО "ВОЭ"   ┆ 3443029580 ┆ 1.2291e7   ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │ 1       ┆ АО "ОЗК"   ┆ 7708632345 ┆ 1.4832e8   ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# └─────────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴────────┴───────────┘

# %%
data.filter(pl.col('Стоимость(руб.) Заказчик').is_null() & 
            pl.col('Обеспечение заявки (руб.)').is_not_null())
# Out:
# shape: (3_252, 26)
# ┌─────────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬────────┬───────────┐
# │ Уровень ┆ Заказчик   ┆ ИНН        ┆ Стоимость( ┆ … ┆ Обеспечени ┆ Обеспечен ┆ РНП    ┆ РНП ранее │
# │ ---     ┆ ---        ┆ заказчика  ┆ руб.)      ┆   ┆ е          ┆ ие контра ┆ сейчас ┆ ---       │
# │ i64     ┆ str        ┆ ---        ┆ Заказчик   ┆   ┆ контракта  ┆ кта, %    ┆ ---    ┆ i64       │
# │         ┆            ┆ str        ┆ ---        ┆   ┆ (руб.)     ┆ ---       ┆ i64    ┆           │
# │         ┆            ┆            ┆ f64        ┆   ┆ ---        ┆ f64       ┆        ┆           │
# │         ┆            ┆            ┆            ┆   ┆ f64        ┆           ┆        ┆           │
# ╞═════════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪════════╪═══════════╡
# │ 2       ┆ АО "ИЭМЗ   ┆ 1831083343 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ "КУПОЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 2       ┆ АО "МОСВОД ┆ 7701984274 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ОКАНАЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 2       ┆ АО "МОСВОД ┆ 7701984274 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ОКАНАЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 2       ┆ АО "МОСВОД ┆ 7701984274 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ОКАНАЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 2       ┆ АО "МОСВОД ┆ 7701984274 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ОКАНАЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ …       ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …         ┆ …      ┆ …         │
# │ 2       ┆ МУП "ВОДОК ┆ 6608001915 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ АНАЛ"      ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 2       ┆ АО "МОСВОД ┆ 7701984274 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ ОКАНАЛ"    ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 2       ┆ БАНК ВТБ   ┆ 7702070139 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ (ПАО)      ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │ 2       ┆ АО "ОЗК"   ┆ 7708632345 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │ 2       ┆ МУП АГО    ┆ 3801006828 ┆ null       ┆ … ┆ null       ┆ null      ┆ 0      ┆ 0         │
# │         ┆ "АНГАРСКИЙ ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# │         ┆ ВОДОКАНАЛ" ┆            ┆            ┆   ┆            ┆           ┆        ┆           │
# └─────────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴────────┴───────────┘

# %%
data.null_count()
# Out:
# shape: (1, 26)
# ┌─────────┬──────────┬─────────────┬────────────┬───┬────────────┬────────────┬────────┬───────────┐
# │ Уровень ┆ Заказчик ┆ ИНН         ┆ Стоимость( ┆ … ┆ Обеспечени ┆ Обеспечени ┆ РНП    ┆ РНП ранее │
# │ ---     ┆ ---      ┆ заказчика   ┆ руб.)      ┆   ┆ е          ┆ е          ┆ сейчас ┆ ---       │
# │ u32     ┆ u32      ┆ ---         ┆ Заказчик   ┆   ┆ контракта  ┆ контракта, ┆ ---    ┆ u32       │
# │         ┆          ┆ u32         ┆ ---        ┆   ┆ (руб.)     ┆ %          ┆ u32    ┆           │
# │         ┆          ┆             ┆ u32        ┆   ┆ ---        ┆ ---        ┆        ┆           │
# │         ┆          ┆             ┆            ┆   ┆ u32        ┆ u32        ┆        ┆           │
# ╞═════════╪══════════╪═════════════╪════════════╪═══╪════════════╪════════════╪════════╪═══════════╡
# │ 0       ┆ 0        ┆ 0           ┆ 36823      ┆ … ┆ 95890      ┆ 79832      ┆ 0      ┆ 0         │
# └─────────┴──────────┴─────────────┴────────────┴───┴────────────┴────────────┴────────┴───────────┘

# %%
new = data.with_columns(pl.when(pl.col('Стоимость(руб.) Заказчик').is_not_null() &
                                pl.col('Обеспечение заявки (руб.)').is_not_null() &
                                pl.col('Обеспечение заявки, %').is_null())
                            .then(pl.col('Обеспечение заявки (руб.)')/pl.col('Стоимость(руб.) Заказчик'))
                            .otherwise(pl.col('Обеспечение заявки, %'))
                            .alias('Обеспечение заявки, %'))
new = new.with_columns(pl.when(pl.col('Стоимость(руб.) Заказчик').is_not_null() &
                                pl.col('Обеспечение заявки (руб.)').is_null() &
                                pl.col('Обеспечение заявки, %').is_not_null())
                            .then(pl.col('Обеспечение заявки, %')*pl.col('Стоимость(руб.) Заказчик'))
                            .otherwise(pl.col('Обеспечение заявки (руб.)'))
                            .alias('Обеспечение заявки (руб.)'))

# %%
new.filter(pl.col('Реестровый номер публикации')=='32009394462')
# Out:
# shape: (1, 26)
# ┌─────────┬──────────┬─────────────┬────────────┬───┬────────────┬────────────┬────────┬───────────┐
# │ Уровень ┆ Заказчик ┆ ИНН         ┆ Стоимость( ┆ … ┆ Обеспечени ┆ Обеспечени ┆ РНП    ┆ РНП ранее │
# │ ---     ┆ ---      ┆ заказчика   ┆ руб.)      ┆   ┆ е          ┆ е          ┆ сейчас ┆ ---       │
# │ i64     ┆ str      ┆ ---         ┆ Заказчик   ┆   ┆ контракта  ┆ контракта, ┆ ---    ┆ i64       │
# │         ┆          ┆ str         ┆ ---        ┆   ┆ (руб.)     ┆ %          ┆ i64    ┆           │
# │         ┆          ┆             ┆ f64        ┆   ┆ ---        ┆ ---        ┆        ┆           │
# │         ┆          ┆             ┆            ┆   ┆ f64        ┆ f64        ┆        ┆           │
# ╞═════════╪══════════╪═════════════╪════════════╪═══╪════════════╪════════════╪════════╪═══════════╡
# │ 1       ┆ АО "ВОЭ" ┆ 3443029580  ┆ 1.2291e7   ┆ … ┆ null       ┆ null       ┆ 0      ┆ 0         │
# └─────────┴──────────┴─────────────┴────────────┴───┴────────────┴────────────┴────────┴───────────┘

# %%
df.loc[291:294]
# Out:
#            inn      price                 num
# 291  223003534  124010.00  301300403220000000
# 292  224003713  491872.08  301300001120000000
# 293  224003713  665000.00  301300001120000000
# 294  224003713  850000.00  301300001120000000
